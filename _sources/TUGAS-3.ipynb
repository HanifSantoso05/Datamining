# %% [markdown]
# # **K-NN IRIS DATASET**

# %% [markdown]
# Algoritma k-Nearest Neighbor adalah algoritma supervised
# learning dimana hasil dari instance yang baru diklasifikasikan berdasarkan mayoritas dari kategori k-tetangga terdekat.
#
# Tujuan dari algoritma ini adalah untuk mengklasifikasikan obyek baru berdasarkan atribut dan sample-sample dari training data.
#
# Algoritma k-Nearest Neighbor menggunakan Neighborhood Classification sebagai nilai prediksi dari nilai instance yang baru. Adapun cara kerja dari algoritma K-NN yaitu :

# %% [markdown]
# 1. Tentukan jumlah tetangga yg akan dilakukan perhitungkan (k), misalnya kita tentukan 3 tetangga terdekat (k = 5).
# 2. hitung jarak setiap tetangga terhadap rumah tersebut, lalu urutkan hasilnya berdasarkan jarak, mulai dari yang terkecil ke yang terbesar.
# 3. ambil 3 (k) tetangga yg paling dekat, lalu tentukan kelas dari data baru tersebut sesuai dengan tetangga terdekatnya.

# %% [markdown]
# Meload data iris melalui link url lalu Membuat Variable untuk mendefinisikan data iris

# %%
import pandas as pd
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
#the imported dataset does not have the required column names so lets add it
colnames = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'Class']
irisdata = pd.read_csv(url, names=colnames)

# %%
irisdata
# Out:
#      sepal-length  sepal-width  petal-length  petal-width           Class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# Melakukan pendefinisian variable x dan y

# %%
# Feature matrix in a object named X
X = irisdata.values[:, 0:4]
# response vector in a object named y
y = irisdata.values[:, 4]

# %%
print(X.shape)
print(y.shape)
# Out:
# (150, 4)
# (150,)

# %% [markdown]
# Menganmbil data latih dan data uji

# %%
# splitting the data into training and test sets (80:20)
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=4)

# %%
#shape of train and test objects
print(X_train.shape)
print(X_test.shape)
# Out:
# (120, 4)
# (30, 4)

# %%
# shape of new y objects
print(y_train.shape)
print(y_test.shape)
# Out:
# (120,)
# (30,)

# %% [markdown]
# Melkukan Import library KNeighborsClassifier dari sklearn

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X,y)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# Melakukan Pengecekkan Accuracy model KNN

# %%
knn.score(X_test, y_test)
# Out:
# 0.9666666666666667

# %% [markdown]
# Melakukan percobaan untuk mencari spesies yang di sesuaikan dengan data baru yang telah di inputkan

# %%
#0 = setosa, 1=versicolor, 2=virginica
classes = {0:'Iris-setosa',1:'Iris-versicolor',2:'Iris-virginica'}

#Making prediction on some unseen data 
#predict for the below two random observations
x_new = [[5.8,	4.0,	1.2,	0.2]]
y_predict = knn.predict(x_new)

print([x_new[0],[y_predict[0]]])
# Out:
# [[5.8, 4.0, 1.2, 0.2], ['Iris-setosa']]
